# %% [markdown]
# ### Raw Data Extraction

# %%
import requests
import pandas as pd
from datetime import datetime, timedelta
import time
import json


# Define the API URL
api_url = "https://api.openaq.org/v2/measurements"

# Define the parameters for the API request
params = {
    "location_id": 275089,
    "parameter": ["pm10", "um003", "humidity", "pm1", "um025", "pm25", "um010", "um050", "um100", "temperature", "pressure", "um005"],
    "limit": 10000  # Increase the limit to get more data per request
}

# Define the date range from January 1, 2020, to now
start_date = datetime(2020, 1, 1)
end_date = datetime.now()

# Initialize an empty list to store data
data_list = []

# Perform API requests in a loop with larger date ranges
while start_date < end_date:
    params["date_from"] = start_date.isoformat() + "Z"

    # Increment the date by three months for the next request
    start_date += timedelta(days=90)  # Increase interval to 3 months

    # Set the end_date for each request as the minimum of the next 3 months or the current end_date
    params["date_to"] = min((start_date, end_date)).isoformat() + "Z"

    # Send the API request
    response = requests.get(api_url, params=params)

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Convert the response to JSON format
        data = response.json()
        measurements = data.get("results", [])
        data_list.extend(measurements)
    else:
        print(f"Error: Failed to fetch data from the API. Status code: {response.status_code}")
        break

    # Introduce a delay of 5 seconds before the next request
    time.sleep(5)

# Create a pandas DataFrame from the list of dictionaries
df = pd.DataFrame(data_list)

# %%
from dateutil.parser import parse

# Step 1: Convert the 'utc' and 'local' fields in the dictionary date objects to Python datetime objects
df['utc_time'] = df['date'].apply(lambda x: parse(x['utc']))
df['local_time'] = df['date'].apply(lambda x: parse(x['local']))

# Step 2: Drop the original 'date' column as it is no longer needed
df.drop('date', axis=1, inplace=True)

# Step 3: Concatenate 'parameter' and 'unit' columns into a new column 'param_unit'
df['param_unit'] = df['parameter'] + '_' + df['unit']

# Step 4: Create a new column to store the indices for each row
df['idx'] = df.groupby('utc_time').cumcount()

df
# Out:
#        locationId location parameter     value           unit  \
# 0          275089  PA_dae4     um025  2.460000  particles/cm³
# 1          275089  PA_dae4     um025  1.725238  particles/cm³
# 2          275089  PA_dae4     um025  3.516333  particles/cm³
# 3          275089  PA_dae4     um025  2.437931  particles/cm³
# 4          275089  PA_dae4     um025  1.622667  particles/cm³
# ...           ...      ...       ...       ...            ...
# 55961      275089  PA_dae4     um005  1.207407  particles/cm³
# 55962      275089  PA_dae4     um005  1.021481  particles/cm³
# 55963      275089  PA_dae4     um005  0.959474  particles/cm³
# 55964      275089  PA_dae4     um005  0.872727  particles/cm³
# 55965      275089  PA_dae4     um005  0.863333  particles/cm³
#
#                                            coordinates country  city  \
# 0      {'latitude': 46.196995, 'longitude': 100.72008}      MN  None
# 1      {'latitude': 46.196995, 'longitude': 100.72008}      MN  None
# 2      {'latitude': 46.196995, 'longitude': 100.72008}      MN  None
# 3      {'latitude': 46.196995, 'longitude': 100.72008}      MN  None
# 4      {'latitude': 46.196995, 'longitude': 100.72008}      MN  None
# ...                                                ...     ...   ...
# 55961  {'latitude': 46.196995, 'longitude': 100.72008}      MN  None
# 55962  {'latitude': 46.196995, 'longitude': 100.72008}      MN  None
# 55963  {'latitude': 46.196995, 'longitude': 100.72008}      MN  None
# 55964  {'latitude': 46.196995, 'longitude': 100.72008}      MN  None
# 55965  {'latitude': 46.196995, 'longitude': 100.72008}      MN  None
#
#        isMobile isAnalysis                  entity       sensorType  \
# 0         False       None  Community Organization  low-cost sensor
# 1         False       None  Community Organization  low-cost sensor
# 2         False       None  Community Organization  low-cost sensor
# 3         False       None  Community Organization  low-cost sensor
# 4         False       None  Community Organization  low-cost sensor
# ...         ...        ...                     ...              ...
# 55961     False       None  Community Organization  low-cost sensor
# 55962     False       None  Community Organization  low-cost sensor
# 55963     False       None  Community Organization  low-cost sensor
# 55964     False       None  Community Organization  low-cost sensor
# 55965     False       None  Community Organization  low-cost sensor
#
#                        utc_time                local_time  \
# 0     2022-01-13 15:00:00+00:00 2022-01-13 14:00:00-01:00
# 1     2022-01-13 16:00:00+00:00 2022-01-13 15:00:00-01:00
# 2     2022-01-13 17:00:00+00:00 2022-01-13 16:00:00-01:00
# 3     2022-01-13 18:00:00+00:00 2022-01-13 17:00:00-01:00
# 4     2022-01-13 19:00:00+00:00 2022-01-13 18:00:00-01:00
# ...                         ...                       ...
# 55961 2023-07-15 15:00:00+00:00 2023-07-15 14:00:00-01:00
# 55962 2023-07-15 16:00:00+00:00 2023-07-15 15:00:00-01:00
# 55963 2023-07-15 17:00:00+00:00 2023-07-15 16:00:00-01:00
# 55964 2023-07-15 18:00:00+00:00 2023-07-15 17:00:00-01:00
# 55965 2023-07-15 19:00:00+00:00 2023-07-15 18:00:00-01:00
#
#                 param_unit  idx
# 0      um025_particles/cm³    0
# 1      um025_particles/cm³    0
# 2      um025_particles/cm³    0
# 3      um025_particles/cm³    0
# 4      um025_particles/cm³    0
# ...                    ...  ...
# 55961  um005_particles/cm³    9
# 55962  um005_particles/cm³    9
# 55963  um005_particles/cm³    9
# 55964  um005_particles/cm³    9
# 55965  um005_particles/cm³    9
#
# [55966 rows x 16 columns]

# %%
# Step 5: Pivot the dataframe to transform 'parameter' values into columns
df_flattened = df.pivot(index=['utc_time', 'locationId', 'local_time'],
                        columns='param_unit', values='value')

# Step 6: Reset the index to get the 'utc_time', 'unit', and other preserved columns back
df_flattened.reset_index(inplace=True)

df_flattened
# Out:
# param_unit                  utc_time  locationId                local_time  \
# 0          2022-01-07 10:00:00+00:00      275089 2022-01-07 09:00:00-01:00
# 1          2022-01-07 11:00:00+00:00      275089 2022-01-07 10:00:00-01:00
# 2          2022-01-07 12:00:00+00:00      275089 2022-01-07 11:00:00-01:00
# 3          2022-01-07 13:00:00+00:00      275089 2022-01-07 12:00:00-01:00
# 4          2022-01-13 15:00:00+00:00      275089 2022-01-13 14:00:00-01:00
# ...                              ...         ...                       ...
# 9796       2023-08-01 11:00:00+00:00      275089 2023-08-01 10:00:00-01:00
# 9797       2023-08-01 12:00:00+00:00      275089 2023-08-01 11:00:00-01:00
# 9798       2023-08-01 13:00:00+00:00      275089 2023-08-01 12:00:00-01:00
# 9799       2023-08-01 14:00:00+00:00      275089 2023-08-01 13:00:00-01:00
# 9800       2023-08-01 15:00:00+00:00      275089 2023-08-01 14:00:00-01:00
#
# param_unit  humidity_%  pm10_µg/m³   pm1_µg/m³  pm25_µg/m³  pressure_mb  \
# 0                  NaN  112.307692   51.469231   92.246154          NaN
# 1                  NaN  659.819231  233.896154  512.476923          NaN
# 2                  NaN  239.985714  103.760714  192.542857          NaN
# 3                  NaN   79.764286   37.514286   65.664286          NaN
# 4                  NaN  267.033333  121.033333  217.600000          NaN
# ...                ...         ...         ...         ...          ...
# 9796         72.291667    0.979167    0.395833    0.766667   805.602083
# 9797         66.692308    3.484615    2.084615    3.161538   805.209231
# 9798         59.700000    1.200000    0.770000    1.120000   805.510000
# 9799         59.000000    1.675000    1.158333    1.583333   806.048333
# 9800         64.142857    0.742857    0.500000    0.742857   806.010000
#
# param_unit  temperature_f  um005_particles/cm³  um010_particles/cm³  \
# 0                     NaN                  NaN             7.793846
# 1                     NaN                  NaN            49.342308
# 2                     NaN                  NaN            13.340000
# 3                     NaN                  NaN             3.754643
# 4                     NaN                  NaN            14.433333
# ...                   ...                  ...                  ...
# 9796            63.708333                  NaN             0.068333
# 9797            65.153846                  NaN             0.193077
# 9798            66.300000                  NaN             0.068000
# 9799            67.083333                  NaN             0.077500
# 9800            67.000000                  NaN             0.038571
#
# param_unit  um025_particles/cm³  um100_particles/cm³
# 0                      1.232308             0.133846
# 1                      8.410385             1.255385
# 2                      2.240714             0.302500
# 3                      0.633214             0.073929
# 4                      2.460000             0.306667
# ...                         ...                  ...
# 9796                   0.002083             0.000000
# 9797                   0.018462             0.000000
# 9798                   0.001000             0.000000
# 9799                   0.002500             0.000000
# 9800                   0.004286             0.000000
#
# [9801 rows x 13 columns]

# %%
# Check for null values in all columns
df_flattened.isnull().sum()
# Out:
# param_unit
# utc_time                  0
# locationId                0
# local_time                0
# humidity_%             8763
# pm10_µg/m³             5982
# pm1_µg/m³                 0
# pm25_µg/m³                0
# pressure_mb            8763
# temperature_f          8763
# um005_particles/cm³    9143
# um010_particles/cm³     630
# um025_particles/cm³       0
# um100_particles/cm³       0
# dtype: int64

# %%
#Drop the parameters that have a lot missing
df_flattened.drop(['humidity_%', 'pm10_µg/m³', 'pressure_mb', 'pressure_mb', 'temperature_f', 'um005_particles/cm³', 'um010_particles/cm³', 'um025_particles/cm³', 'um100_particles/cm³'], axis=1, inplace=True)

df_flattened
# Out:
# param_unit                  utc_time  locationId                local_time  \
# 0          2022-01-07 10:00:00+00:00      275089 2022-01-07 09:00:00-01:00
# 1          2022-01-07 11:00:00+00:00      275089 2022-01-07 10:00:00-01:00
# 2          2022-01-07 12:00:00+00:00      275089 2022-01-07 11:00:00-01:00
# 3          2022-01-07 13:00:00+00:00      275089 2022-01-07 12:00:00-01:00
# 4          2022-01-13 15:00:00+00:00      275089 2022-01-13 14:00:00-01:00
# ...                              ...         ...                       ...
# 9796       2023-08-01 11:00:00+00:00      275089 2023-08-01 10:00:00-01:00
# 9797       2023-08-01 12:00:00+00:00      275089 2023-08-01 11:00:00-01:00
# 9798       2023-08-01 13:00:00+00:00      275089 2023-08-01 12:00:00-01:00
# 9799       2023-08-01 14:00:00+00:00      275089 2023-08-01 13:00:00-01:00
# 9800       2023-08-01 15:00:00+00:00      275089 2023-08-01 14:00:00-01:00
#
# param_unit   pm1_µg/m³  pm25_µg/m³
# 0            51.469231   92.246154
# 1           233.896154  512.476923
# 2           103.760714  192.542857
# 3            37.514286   65.664286
# 4           121.033333  217.600000
# ...                ...         ...
# 9796          0.395833    0.766667
# 9797          2.084615    3.161538
# 9798          0.770000    1.120000
# 9799          1.158333    1.583333
# 9800          0.500000    0.742857
#
# [9801 rows x 5 columns]

# %% [markdown]
# ### Prepare Data For Grading

# %%
#Drop the parameters that have a lot missing
df_flattened.drop(['locationId'], axis=1, inplace=True)

# Set the 'Timestamp' column as the DataFrame index
df_flattened.set_index('utc_time', inplace=True)

# Resample the data to daily intervals and calculate the daily average
daily_averages = df_flattened.resample('D').mean().reset_index()

daily_averages = daily_averages.round({'pm1_µg/m³': 0, 'pm25_µg/m³': 1})

daily_averages
# Out:
# /var/folders/5b/1b64wf4d3lsfd20lg09_h0xh0000gp/T/ipykernel_60691/880992179.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   daily_averages = df_flattened.resample('D').mean().reset_index()
# param_unit                  utc_time  pm1_µg/m³  pm25_µg/m³
# 0          2022-01-07 00:00:00+00:00      107.0       215.7
# 1          2022-01-08 00:00:00+00:00        NaN         NaN
# 2          2022-01-09 00:00:00+00:00        NaN         NaN
# 3          2022-01-10 00:00:00+00:00        NaN         NaN
# 4          2022-01-11 00:00:00+00:00        NaN         NaN
# ..                               ...        ...         ...
# 567        2023-07-28 00:00:00+00:00        0.0         0.5
# 568        2023-07-29 00:00:00+00:00        1.0         2.3
# 569        2023-07-30 00:00:00+00:00        1.0         1.9
# 570        2023-07-31 00:00:00+00:00        1.0         1.4
# 571        2023-08-01 00:00:00+00:00        1.0         1.0
#
# [572 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# Assuming 'value1' and 'value2' are the column names for the two series you want to plot
plt.figure(figsize=(10, 6))
plt.plot(daily_averages['utc_time'], daily_averages['pm1_µg/m³'], label='pm1_µg/m³', color='blue')
plt.plot(daily_averages['utc_time'], daily_averages['pm25_µg/m³'], label='pm25_µg/m³', color='green')
plt.xlabel('Date')
plt.ylabel('µg/m³')
plt.title('Time Series of PM2.5 and PM10')
plt.legend()
plt.grid(True)
plt.show()

# %%
def calculate_aqi(concentration, breakpoints):
    """
    Calculates the Air Quality Index (AQI) for a given concentration using EPA's AQI calculation method.

    Args:
        concentration (float): The concentration of a pollutant (e.g., PM10 or PM2.5).
        breakpoints (list): List of tuples containing AQI breakpoints and their corresponding concentration ranges.

    Returns:
        int: The calculated AQI value.
    """
    for i in range(1, len(breakpoints)):
        if concentration <= breakpoints[i][1]:
            c_low = breakpoints[i - 1][1]
            c_high = breakpoints[i][1]
            i_low = breakpoints[i - 1][0]
            i_high = breakpoints[i][0]
            return round(((i_high - i_low) / (c_high - c_low)) * (concentration - c_low) + i_low)

    raise ValueError("The concentration value is above the highest AQI breakpoint.")

def get_aqi_category(aqi_value):
    """
    Returns the AQI category based on the AQI value.

    Args:
        aqi_value (int): The calculated AQI value.

    Returns:
        str: The AQI category.
    """
    if aqi_value <= 50:
        return "Good"
    elif aqi_value <= 100:
        return "Moderate"
    elif aqi_value <= 150:
        return "Unhealthy for Sensitive Groups"
    elif aqi_value <= 200:
        return "Unhealthy"
    elif aqi_value <= 300:
        return "Very Unhealthy"
    else:
        return "None"

def add_aqi_column(dataframe):
    """
    Adds a new column 'AQI' to the given DataFrame using the PM10 and PM2.5 values.

    Args:
        dataframe (pandas.DataFrame): The DataFrame containing 'PM10' and 'PM2.5' columns.

    Returns:
        pandas.DataFrame: The DataFrame with an additional 'AQI' column.
    """
    breakpoints_pm10 = [
        (0, 0), (50, 54), (100, 154), (150, 254), (200, 354), (300, 424), (400, 504), (500, 604)

    ]

    breakpoints_pm25 = [
        (0, 0), (50, 12), (100, 35.4), (150, 55.4), (200, 150.4), (300, 250.4), (400, 350.4), (500, 500.4)
    ]

    # Calculate AQI for each row in the DataFrame based on PM10 and PM2.5 values
    aqi_values = []
    for _, row in dataframe.iterrows():
        pm10 = row['pm1_µg/m³']
        pm25 = row['pm25_µg/m³']

        if pd.notna(pm10) and pd.notna(pm25):  # Check for NaN values
            aqi_pm10 = calculate_aqi(pm10, breakpoints_pm10)
            aqi_pm25 = calculate_aqi(pm25, breakpoints_pm25)

            # Use the maximum AQI value from both PM10 and PM2.5 to represent the overall AQI
            aqi = max(aqi_pm10, aqi_pm25)

            aqi_values.append(aqi)
        else:
            aqi_values.append(None)  # Set AQI to None for rows with NaN values

    # Add the AQI column to the DataFrame
    dataframe['AQI'] = aqi_values

    return dataframe

# Assuming you have a pandas DataFrame named 'air_quality_data' with 'PM10' and 'PM2.5' columns
# You can add the 'AQI' column by calling the function add_aqi_column
air_quality_data = add_aqi_column(daily_averages)

# Adding a new column for AQI category
air_quality_data['AQI Category'] = air_quality_data['AQI'].apply(get_aqi_category)

air_quality_data
# Out:
# param_unit                  utc_time  pm1_µg/m³  pm25_µg/m³    AQI  \
# 0          2022-01-07 00:00:00+00:00      107.0       215.7  265.0
# 1          2022-01-08 00:00:00+00:00        NaN         NaN    NaN
# 2          2022-01-09 00:00:00+00:00        NaN         NaN    NaN
# 3          2022-01-10 00:00:00+00:00        NaN         NaN    NaN
# 4          2022-01-11 00:00:00+00:00        NaN         NaN    NaN
# ..                               ...        ...         ...    ...
# 567        2023-07-28 00:00:00+00:00        0.0         0.5    2.0
# 568        2023-07-29 00:00:00+00:00        1.0         2.3   10.0
# 569        2023-07-30 00:00:00+00:00        1.0         1.9    8.0
# 570        2023-07-31 00:00:00+00:00        1.0         1.4    6.0
# 571        2023-08-01 00:00:00+00:00        1.0         1.0    4.0
#
# param_unit    AQI Category
# 0           Very Unhealthy
# 1                     None
# 2                     None
# 3                     None
# 4                     None
# ..                     ...
# 567                   Good
# 568                   Good
# 569                   Good
# 570                   Good
# 571                   Good
#
# [572 rows x 5 columns]

# %%
# Out:
# Decimal('173')
